# %%
import pandas as pd

# import necessaire à la création des widgets
from IPython.display import display, clear_output, HTML, Markdown 
import ipywidgets as widgets

# %% [markdown]
# ### Fichier Buchanan-J

# %%
# préciser le chemin du fichier à lire
cheminDuFichierCSV = "./../data/dictionary/1757_Buchanan-J.csv" 

# demander à pandas de lire le fichier et garder ce tableau accessible dans une variable
dfDicoBuch = pd.read_csv(cheminDuFichierCSV, delimiter=";", encoding="utf8")

# afficher à l'écran un échantillon du tableau
dfDicoBuch.sample(n=5)
# Out:
#        nbSyll             pron origin warning remarques POS  lineId  pageId
# 14596       2       vĭʹſc_o_us    NaN     NaN       NaN  a.    54.0     224
# 582         6  antĭve˘nēʹrĭals     L.     NaN       NaN  n.    44.0      27
# 1484        1              boy    NaN     NaN       NaN  n.    13.0      40
# 5545        2         gauʹdies    NaN     NaN       NaN  n.    64.0      96
# 2831        5    convĕrsaʹtion     F.     NaN       NaN  n.    67.0      58

# %% [markdown]
# ### Fichier à intégrer

# %%
# préciser le chemin du fichier à lire
cheminDuFichierCSV = "./../data/dictionary/Buchanan_PronChar_counts.csv" 

# demander à pandas de lire le fichier et garder ce tableau accessible dans une variable
dfDicoPron = pd.read_csv(cheminDuFichierCSV, delimiter=";", encoding="utf8")

# afficher à l'écran un échantillon du tableau
dfDicoPron
# Out:
#    char    occ graph
# 0     a   3207     a
# 1     ʹ  12725   NaN
# 2     b   2288     b
# 3     ă   4533     a
# 4     c   5500     c
# ..  ...    ...   ...
# 68    á      1     a
# 69    I      1     l
# 70    х      2     x
# 71    р      1     p
# 72    ï      1     i
#
# [73 rows x 3 columns]

# %%
dfDicoPron = dfDicoPron.dropna()

# %%
dfDicoPron
# Out:
#    char   occ graph
# 0     a  3207     a
# 2     b  2288     b
# 3     ă  4533     a
# 4     c  5500     c
# 5     u  1623     u
# ..  ...   ...   ...
# 68    á     1     a
# 69    I     1     l
# 70    х     2     x
# 71    р     1     p
# 72    ï     1     i
#
# [65 rows x 3 columns]

# %%
def BucToPron(strSampa, dfMapping):
    ipaRes = ""
    
    for valSampa in strSampa:
        dfRowFinded = dfMapping[dfMapping['char']==valSampa]

        if len(dfRowFinded==1):
            ipaRes+=dfRowFinded.iloc[0]['graph']
        else:
            ipaRes+=''
    return ipaRes

# %%
dfDicoPronRich = dfDicoBuch.sample(n=100).copy()

dfDicoBuch['motVedette'] = dfDicoBuch.apply(lambda x: BucToPron(x['pron'], dfDicoPron),1)

# %%
dfDicoBuch
# Out:
#        nbSyll        pron origin warning remarques POS  lineId  pageId  \
# 0           3     aʹbăcus    NaN     NaN       NaN  n.     2.0      19
# 1           2      ăbăʹft    NaN     NaN       NaN  p.     3.0      19
# 2           3  ăbaiʹſănce     F.     NaN       NaN  n.     4.0      19
# 3           3    ābăʹndon     F.     NaN       NaN  v.     5.0      19
# 4           4  ābăʹndŏned    NaN     NaN       NaN  a.     6.0      19
# ...       ...         ...    ...     ...       ...  ..     ...     ...
# 15795       4  zōŏʹgrăphy     G.     NaN       NaN  n.    19.0     241
# 15796       4  zōŏʹphytès     G.     NaN       NaN  n.    20.0     241
# 15797       4  zōŏʹphŏric     G.     NaN       NaN  n.    21.0     241
# 15798       4  zōŏʹtŏmiſt     G.     NaN       NaN  n.    22.0     241
# 15799       3     zŏʹtĭcā     G.     NaN       NaN  n.    23.0     241
#
#         Headword motVedette
# 0         abacus     abacus
# 1          abaft      abaft
# 2      abaisance  abaisance
# 3        abandon    abandon
# 4      abandoned  abandoned
# ...          ...        ...
# 15795  zoography  zoography
# 15796  zoophytes  zoophytes
# 15797  zoophoric  zoophoric
# 15798  zootomist  zootomist
# 15799     zotica     zotica
#
# [15800 rows x 10 columns]
